# %% [markdown]
# # Jupyter Integration with cuXfilter

# %% [markdown]
# ### Importing the required module

# %%
from cuXfilter import cuXfilter

# %% [markdown]
# ### Initializing the cuXfilter object with dataset name, server_ip and port

# %%
cux = cuXfilter.cuXfilter(dataset='146M_predictions_v2', server_ip="http://localhost")

# %% [markdown]
# ## Method 1: load all charts in a single cell

# %%
cux.dimension(data={"delinquency_12_prediction":{"type":"histogram","bin_size":90},
                   "dti":{"type":"histogram","bin_size":20},
                   "borrower_credit_score":{"type":"histogram","bin_size":50}}, name="combined")
# Out:
#            <iframe name="combined" class="combined" width="100%" srcdoc="
# &lt;!DOCTYPE html&gt;
# &lt;html&gt;
#   &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot; /&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;
#     &lt;title&gt;RAPIDS Viz Demo&lt;/title&gt;
#   &lt;link rel=&quot;shortcut icon&quot; href=&quot;./favicon.png&quot;&gt;&lt;style&gt;
#
#   @import url(https://fonts.googleapis.com/css?family=Cabin:400,700);
# /* global  styles */
# body {
#   font-family: &#x27;Cabin&#x27;, sans-serif;
#   font-size: 15px;
#   margin: 0;
#   padding: 0;
#   background-color: white;
#   color: black; }
#
# /* barChart Styles */
# /* input range slider */
# .input-range {
#   z-index: 9999; }
#
# .input-range {
#   height: 1rem;
#   position: relative;
#   width: 100%; }
#
# .input-range__slider {
#   appearance: none;
#   background: black;
#   border: 1px solid black;
#   border-radius: 100%;
#   cursor: pointer;
#   display: block;
#   height: 1rem;
#   margin-left: -0.5rem;
#   margin-top: -0.65rem;
#   outline: none;
#   position: absolute;
#   top: 50%;
#   transition: transform 0.15s ease-out, box-shadow 0.15s ease-out;
#   width: 1rem; }
#
# .input-range__slider:active {
#   transform: scale(1.3); }
#
# .input-range__slider:focus {
#   box-shadow: 0 0 0 5px rgba(63, 81, 181, 0.2); }
#
# .input-range--disabled .input-range__slider {
#   background: black;
#   border: 1px solid rgba(63, 81, 181, 0.2);
#   box-shadow: none;
#   transform: none; }
#
# .input-range__slider-container {
#   transition: left 0.15s ease-out; }
#
# .input-range__label {
#   color: black;
#   font-family: &quot;Helvetica Neue&quot;, san-serif;
#   font-size: 0.8rem;
#   transform: translateZ(0);
#   white-space: nowrap; }
#
# .input-range__label--min,
# .input-range__label--max {
#   bottom: -1.4rem;
#   position: absolute; }
#
# .input-range__label--min {
#   left: 0; }
#
# .input-range__label--max {
#   right: 0; }
#
# .input-range__label--value {
#   position: absolute;
#   top: -1.8rem; }
#
# .input-range__label-container {
#   left: -50%;
#   position: relative; }
#
# .input-range__label--max .input-range__label-container {
#   left: 50%; }
#
# .input-range__track {
#   background: black;
#   border-radius: 0.3rem;
#   cursor: pointer;
#   display: block;
#   height: 0.3rem;
#   position: relative;
#   transition: left 0.15s ease-out, width 0.15s ease-out; }
#
# .input-range--disabled .input-range__track {
#   background: black; }
#
# .input-range__track--background {
#   left: 0;
#   margin-top: -0.15rem;
#   position: absolute;
#   right: 0;
#   top: 50%; }
#
# .input-range__track--active {
#   background: black; }
#
# /* mapchartChart Styles */
# /* full screen container */
# .mapchart {
#   position: relative;
#   width: 90%;
#   height: 80%;
#   margin-left: 5%;
#   padding-left: 1%;
#   background-color: white; }
#
# /* legend seciton */
# .mapchart-legend-container {
#   z-index: 999;
#   position: absolute;
#   display: inline-block;
#   background-color: white;
#   top: 0;
#   left: 0;
#   width: 18rem;
#   height: 100%;
#   font-variant: small-caps;
#   color: white;
#   box-shadow: 0 0 2px 1px white; }
#
# .mapchart-legend-section {
#   position: relative;
#   margin: 1.5rem 2rem;
#   z-index: 10; }
#
# .mapchart-legend-section-dial {
#   position: relative;
#   margin: 0rem 1rem;
#   z-index: 10; }
#
# .mapchart-legend-section-1col {
#   position: relative;
#   text-align: center;
#   }
#
# .mapchart-legend-section-2col {
#   position: relative;
#   width: 50%;
#   display: inline-block;
#   text-align: center; }
#
# .mapchart-legend-heading {
#   font-size: 1.3rem; }
#
# .mapchart-circ-value {
#   position: absolute;
#   text-align: center;
#   color: black;
#   width: 100%;
#   top: 36%;
#   font-size: 1.3rem; }
#
# .mapchart-key-ul {
#   list-style-type: none;
#   padding-left: 0;
#   margin: 0; }
#
# .mapchart-perf-title {
#   font-size: 1.1rem; }
#
# .mapchart-perf-cube {
#   display: inline-block;
#   vertical-align: top;
#   margin-top: 0.25rem;
#   font-size: 1.2rem; }
#
# .legend-img {
#   width: 2rem; }
#
# .mapchart-bank-list {
#   font-size: 0.9rem;
#   width: 100%; }
#
# .mapchart-perf {
#   display: inline-block;
#   width: 2rem;
#   height: 0.9rem;
#   margin-right: 0.25rem;
#   text-align: center; }
#
# .mapchart-sel0 {
#   background-color: #1082d6; }
#
# .mapchart-sel1 {
#   background-color: #6baed6; }
#
# .mapchart-sel2 {
#   background-color: #7b8ed8; }
#
# .mapchart-sel3 {
#   background-color: #e26798; }
#
# .mapchart-sel4 {
#   background-color: #ff0068; }
#
# .mapchart-legend-button {
#   color: #888888;
#   width: 100%;
#   font-size: 1.2rem;
#   padding: 1.25rem 0rem;
#   text-align: center;
#   background-color: #1f1f1f;
#   cursor: pointer; }
#
# .mapchart-legend-button:hover {
#   color: white; }
#
# .a-button {
#   text-decoration: none;
#   color: #888888; }
#
# .a-button:hover {
#   color: white; }
#
# .mapchart-legend-button-small {
#   width: 100%;
#   color: #888888;
#   font-size: 1.2rem;
#   padding: 0.25rem 0rem;
#   text-align: center;
#   background-color: #1f1f1f;
#   cursor: pointer; }
#
# .mapchart-legend-button-small:hover {
#   color: white; }
#
# .mapchart-legend-sink {
#   position: absolute;
#   bottom: 0;
#   width: 100%; }
#
# /* map section */
# .mapboxgl-ctrl.mapboxgl-ctrl-attrib {
#   display: none; }
#
# .mapboxgl-ctrl-bottom-left {
#   display: none; }
#
# .mapchart-heading-body {
#   position: relative;
#   text-align: center;
#   z-index: 999;
#   margin-left: 18rem;
#   width: calc(100% - 18rem);
#   background-color: rgba(25, 26, 26, 0.8); }
#
# .mapchart-heading-container {
#   display: inline-block; }
#
# .mapchart-header-title {
#   padding-top: 0.7rem;
#   font-size: 2rem;
#   font-variant: small-caps;
#   text-align: center; }
#
# .mapchart-total-bar-cudf {
#   text-align: center;
#   height: 0.25rem;
#   width: 100%;
#   margin-bottom: 0.7rem;
#   background-color: #76b900;
#   transition: all 0.6s ease; }
#
# .mapchart-total-bar-pandas {
#   text-align: center;
#   height: 0.25rem;
#   width: 100%;
#   margin-bottom: 0.7rem;
#   background-color: #0071c5;
#   transition: all 0.6s ease; }
#
# .percent {
#   font-size: 1.3rem; }
#
# .mapchart-map-body {
#   position: absolute;
#   vertical-align: top;
#   display: inline-block;
#   background-color: rgba(0, 0, 0, 0.3);
#   width: 100%;
#   height: 100%; }
#
# /* chart section */
# .mapchart-chart-body {
#   position: relative;
#   background-color: rgba(25, 26, 26, 0.8); }
#
# .mapchart-col1-container {
#   display: inline-block;
#   vertical-align: top;
#   position: relative;
#   margin-left: 10%;
#   width: 80%;
#   height: 80%; }
#
# .mapchart-col2-container {
#   display: inline-block;
#   vertical-align: top;
#   position: relative;
#   width: 45%;
#   height: 100%;
#   margin: 2%; }
#
# .mapchart-col3-container {
#   display: inline-block;
#   vertical-align: top;
#   position: relative;
#   width: 28.32%;
#   height: 100%;
#   padding: 0% 2%; }
#
# .mapChart-chart-reset {
#   cursor: pointer;
#   width: 100%;
#   text-align: center;
#   margin-top: 1rem;
#   font-variant: small-caps;
#   color: #888888; }
#
# .mapChart-chart-reset:hover {
#   color: white; }
#
# .VictoryContainer {
#   overflow: hidden;
#   z-index: 99; }
#
# /* super wide screens */
# @media only screen and (min-width: 2000px) {
#   .mapchart-col2-container {
#     position: relative;
#     width: 92%;
#     height: 42%;
#     padding: 2% 2%; }
#   .mapchart-col3-container {
#     position: relative;
#     width: 80%;
#     height: 22%;
#     padding: 7% 10%; } }
#
# /* status stripes */
# .stripes {
#   transition: all 0.6s ease;
#   animation: barberpole 1s linear infinite;
#   background-size: 30px 30px;
#   background-image: linear-gradient(45deg, rgba(0, 0, 0, 0.2) 25%, transparent 25%, transparent 50%, rgba(0, 0, 0, 0.2) 50%, rgba(0, 0, 0, 0.2) 75%, transparent 75%, transparent); }
#
# @keyframes barberpole {
#   from {
#     background-position: 0 0; }
#   to {
#     background-position: 60px 30px; } }
#
# &lt;/style&gt;&lt;/head&gt;
#   &lt;body&gt;
#   	&lt;div id=&quot;root&quot;&gt;&lt;/div&gt;
#  &lt;script type=&quot;text/javascript&quot;&gt;
#  !function(e){var t={};function n(r){if(t[r])return t[r].exports;var o=t[r]={i:r,l:!1,exports:{}};return e[r].call(o.exports,o,o.exports,n),o.l=!0,o.exports}n.m=e,n.c=t,n.d=function(e,t,r){n.o(e,t)||Object.defineProperty(e,t,{enumerable:!0,get:r})},n.r=function(e){&quot;undefined&quot;!=typeof Symbol&amp;&amp;Symbol.toStringTag&amp;&amp;Object.defineProperty(e,Symbol.toStringTag,{value:&quot

# %%
cux.render()

# %% [markdown]
# ## Method 2: load each chart in an individual cell

# %%
cux.dimension(data={"delinquency_12_prediction":{"type":"histogram","bin_size":90}})
# Out:
#            <iframe name="delinquency_12_prediction" class="delinquency_12_prediction" width="100%" srcdoc="
# &lt;!DOCTYPE html&gt;
# &lt;html&gt;
#   &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot; /&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;
#     &lt;title&gt;RAPIDS Viz Demo&lt;/title&gt;
#   &lt;link rel=&quot;shortcut icon&quot; href=&quot;./favicon.png&quot;&gt;&lt;style&gt;
#
#   @import url(https://fonts.googleapis.com/css?family=Cabin:400,700);
# /* global  styles */
# body {
#   font-family: &#x27;Cabin&#x27;, sans-serif;
#   font-size: 15px;
#   margin: 0;
#   padding: 0;
#   background-color: white;
#   color: black; }
#
# /* barChart Styles */
# /* input range slider */
# .input-range {
#   z-index: 9999; }
#
# .input-range {
#   height: 1rem;
#   position: relative;
#   width: 100%; }
#
# .input-range__slider {
#   appearance: none;
#   background: black;
#   border: 1px solid black;
#   border-radius: 100%;
#   cursor: pointer;
#   display: block;
#   height: 1rem;
#   margin-left: -0.5rem;
#   margin-top: -0.65rem;
#   outline: none;
#   position: absolute;
#   top: 50%;
#   transition: transform 0.15s ease-out, box-shadow 0.15s ease-out;
#   width: 1rem; }
#
# .input-range__slider:active {
#   transform: scale(1.3); }
#
# .input-range__slider:focus {
#   box-shadow: 0 0 0 5px rgba(63, 81, 181, 0.2); }
#
# .input-range--disabled .input-range__slider {
#   background: black;
#   border: 1px solid rgba(63, 81, 181, 0.2);
#   box-shadow: none;
#   transform: none; }
#
# .input-range__slider-container {
#   transition: left 0.15s ease-out; }
#
# .input-range__label {
#   color: black;
#   font-family: &quot;Helvetica Neue&quot;, san-serif;
#   font-size: 0.8rem;
#   transform: translateZ(0);
#   white-space: nowrap; }
#
# .input-range__label--min,
# .input-range__label--max {
#   bottom: -1.4rem;
#   position: absolute; }
#
# .input-range__label--min {
#   left: 0; }
#
# .input-range__label--max {
#   right: 0; }
#
# .input-range__label--value {
#   position: absolute;
#   top: -1.8rem; }
#
# .input-range__label-container {
#   left: -50%;
#   position: relative; }
#
# .input-range__label--max .input-range__label-container {
#   left: 50%; }
#
# .input-range__track {
#   background: black;
#   border-radius: 0.3rem;
#   cursor: pointer;
#   display: block;
#   height: 0.3rem;
#   position: relative;
#   transition: left 0.15s ease-out, width 0.15s ease-out; }
#
# .input-range--disabled .input-range__track {
#   background: black; }
#
# .input-range__track--background {
#   left: 0;
#   margin-top: -0.15rem;
#   position: absolute;
#   right: 0;
#   top: 50%; }
#
# .input-range__track--active {
#   background: black; }
#
# /* mapchartChart Styles */
# /* full screen container */
# .mapchart {
#   position: relative;
#   width: 90%;
#   height: 80%;
#   margin-left: 5%;
#   padding-left: 1%;
#   background-color: white; }
#
# /* legend seciton */
# .mapchart-legend-container {
#   z-index: 999;
#   position: absolute;
#   display: inline-block;
#   background-color: white;
#   top: 0;
#   left: 0;
#   width: 18rem;
#   height: 100%;
#   font-variant: small-caps;
#   color: white;
#   box-shadow: 0 0 2px 1px white; }
#
# .mapchart-legend-section {
#   position: relative;
#   margin: 1.5rem 2rem;
#   z-index: 10; }
#
# .mapchart-legend-section-dial {
#   position: relative;
#   margin: 0rem 1rem;
#   z-index: 10; }
#
# .mapchart-legend-section-1col {
#   position: relative;
#   text-align: center;
#   }
#
# .mapchart-legend-section-2col {
#   position: relative;
#   width: 50%;
#   display: inline-block;
#   text-align: center; }
#
# .mapchart-legend-heading {
#   font-size: 1.3rem; }
#
# .mapchart-circ-value {
#   position: absolute;
#   text-align: center;
#   color: black;
#   width: 100%;
#   top: 36%;
#   font-size: 1.3rem; }
#
# .mapchart-key-ul {
#   list-style-type: none;
#   padding-left: 0;
#   margin: 0; }
#
# .mapchart-perf-title {
#   font-size: 1.1rem; }
#
# .mapchart-perf-cube {
#   display: inline-block;
#   vertical-align: top;
#   margin-top: 0.25rem;
#   font-size: 1.2rem; }
#
# .legend-img {
#   width: 2rem; }
#
# .mapchart-bank-list {
#   font-size: 0.9rem;
#   width: 100%; }
#
# .mapchart-perf {
#   display: inline-block;
#   width: 2rem;
#   height: 0.9rem;
#   margin-right: 0.25rem;
#   text-align: center; }
#
# .mapchart-sel0 {
#   background-color: #1082d6; }
#
# .mapchart-sel1 {
#   background-color: #6baed6; }
#
# .mapchart-sel2 {
#   background-color: #7b8ed8; }
#
# .mapchart-sel3 {
#   background-color: #e26798; }
#
# .mapchart-sel4 {
#   background-color: #ff0068; }
#
# .mapchart-legend-button {
#   color: #888888;
#   width: 100%;
#   font-size: 1.2rem;
#   padding: 1.25rem 0rem;
#   text-align: center;
#   background-color: #1f1f1f;
#   cursor: pointer; }
#
# .mapchart-legend-button:hover {
#   color: white; }
#
# .a-button {
#   text-decoration: none;
#   color: #888888; }
#
# .a-button:hover {
#   color: white; }
#
# .mapchart-legend-button-small {
#   width: 100%;
#   color: #888888;
#   font-size: 1.2rem;
#   padding: 0.25rem 0rem;
#   text-align: center;
#   background-color: #1f1f1f;
#   cursor: pointer; }
#
# .mapchart-legend-button-small:hover {
#   color: white; }
#
# .mapchart-legend-sink {
#   position: absolute;
#   bottom: 0;
#   width: 100%; }
#
# /* map section */
# .mapboxgl-ctrl.mapboxgl-ctrl-attrib {
#   display: none; }
#
# .mapboxgl-ctrl-bottom-left {
#   display: none; }
#
# .mapchart-heading-body {
#   position: relative;
#   text-align: center;
#   z-index: 999;
#   margin-left: 18rem;
#   width: calc(100% - 18rem);
#   background-color: rgba(25, 26, 26, 0.8); }
#
# .mapchart-heading-container {
#   display: inline-block; }
#
# .mapchart-header-title {
#   padding-top: 0.7rem;
#   font-size: 2rem;
#   font-variant: small-caps;
#   text-align: center; }
#
# .mapchart-total-bar-cudf {
#   text-align: center;
#   height: 0.25rem;
#   width: 100%;
#   margin-bottom: 0.7rem;
#   background-color: #76b900;
#   transition: all 0.6s ease; }
#
# .mapchart-total-bar-pandas {
#   text-align: center;
#   height: 0.25rem;
#   width: 100%;
#   margin-bottom: 0.7rem;
#   background-color: #0071c5;
#   transition: all 0.6s ease; }
#
# .percent {
#   font-size: 1.3rem; }
#
# .mapchart-map-body {
#   position: absolute;
#   vertical-align: top;
#   display: inline-block;
#   background-color: rgba(0, 0, 0, 0.3);
#   width: 100%;
#   height: 100%; }
#
# /* chart section */
# .mapchart-chart-body {
#   position: relative;
#   background-color: rgba(25, 26, 26, 0.8); }
#
# .mapchart-col1-container {
#   display: inline-block;
#   vertical-align: top;
#   position: relative;
#   margin-left: 10%;
#   width: 80%;
#   height: 80%; }
#
# .mapchart-col2-container {
#   display: inline-block;
#   vertical-align: top;
#   position: relative;
#   width: 45%;
#   height: 100%;
#   margin: 2%; }
#
# .mapchart-col3-container {
#   display: inline-block;
#   vertical-align: top;
#   position: relative;
#   width: 28.32%;
#   height: 100%;
#   padding: 0% 2%; }
#
# .mapChart-chart-reset {
#   cursor: pointer;
#   width: 100%;
#   text-align: center;
#   margin-top: 1rem;
#   font-variant: small-caps;
#   color: #888888; }
#
# .mapChart-chart-reset:hover {
#   color: white; }
#
# .VictoryContainer {
#   overflow: hidden;
#   z-index: 99; }
#
# /* super wide screens */
# @media only screen and (min-width: 2000px) {
#   .mapchart-col2-container {
#     position: relative;
#     width: 92%;
#     height: 42%;
#     padding: 2% 2%; }
#   .mapchart-col3-container {
#     position: relative;
#     width: 80%;
#     height: 22%;
#     padding: 7% 10%; } }
#
# /* status stripes */
# .stripes {
#   transition: all 0.6s ease;
#   animation: barberpole 1s linear infinite;
#   background-size: 30px 30px;
#   background-image: linear-gradient(45deg, rgba(0, 0, 0, 0.2) 25%, transparent 25%, transparent 50%, rgba(0, 0, 0, 0.2) 50%, rgba(0, 0, 0, 0.2) 75%, transparent 75%, transparent); }
#
# @keyframes barberpole {
#   from {
#     background-position: 0 0; }
#   to {
#     background-position: 60px 30px; } }
#
# &lt;/style&gt;&lt;/head&gt;
#   &lt;body&gt;
#   	&lt;div id=&quot;root&quot;&gt;&lt;/div&gt;
#  &lt;script type=&quot;text/javascript&quot;&gt;
#  !function(e){var t={};function n(r){if(t[r])return t[r].exports;var o=t[r]={i:r,l:!1,exports:{}};return e[r].call(o.exports,o,o.exports,n),o.l=!0,o.exports}n.m=e,n.c=t,n.d=function(e,t,r){n.o(e,t)||Object.defineProperty(e,t,{enumerable:!0,get:r})},n.r=function(e){&quot;undefined&quot;!=typeof Symbol&amp;&amp;Symbol.toStringTag&amp;&amp;Object.defineProperty

# %%
cux.dimension(data={"dti":{"type":"histogram","bin_size":20}})
# Out:
#            <iframe name="dti" class="dti" width="100%" srcdoc="
# &lt;!DOCTYPE html&gt;
# &lt;html&gt;
#   &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot; /&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;
#     &lt;title&gt;RAPIDS Viz Demo&lt;/title&gt;
#   &lt;link rel=&quot;shortcut icon&quot; href=&quot;./favicon.png&quot;&gt;&lt;style&gt;
#
#   @import url(https://fonts.googleapis.com/css?family=Cabin:400,700);
# /* global  styles */
# body {
#   font-family: &#x27;Cabin&#x27;, sans-serif;
#   font-size: 15px;
#   margin: 0;
#   padding: 0;
#   background-color: white;
#   color: black; }
#
# /* barChart Styles */
# /* input range slider */
# .input-range {
#   z-index: 9999; }
#
# .input-range {
#   height: 1rem;
#   position: relative;
#   width: 100%; }
#
# .input-range__slider {
#   appearance: none;
#   background: black;
#   border: 1px solid black;
#   border-radius: 100%;
#   cursor: pointer;
#   display: block;
#   height: 1rem;
#   margin-left: -0.5rem;
#   margin-top: -0.65rem;
#   outline: none;
#   position: absolute;
#   top: 50%;
#   transition: transform 0.15s ease-out, box-shadow 0.15s ease-out;
#   width: 1rem; }
#
# .input-range__slider:active {
#   transform: scale(1.3); }
#
# .input-range__slider:focus {
#   box-shadow: 0 0 0 5px rgba(63, 81, 181, 0.2); }
#
# .input-range--disabled .input-range__slider {
#   background: black;
#   border: 1px solid rgba(63, 81, 181, 0.2);
#   box-shadow: none;
#   transform: none; }
#
# .input-range__slider-container {
#   transition: left 0.15s ease-out; }
#
# .input-range__label {
#   color: black;
#   font-family: &quot;Helvetica Neue&quot;, san-serif;
#   font-size: 0.8rem;
#   transform: translateZ(0);
#   white-space: nowrap; }
#
# .input-range__label--min,
# .input-range__label--max {
#   bottom: -1.4rem;
#   position: absolute; }
#
# .input-range__label--min {
#   left: 0; }
#
# .input-range__label--max {
#   right: 0; }
#
# .input-range__label--value {
#   position: absolute;
#   top: -1.8rem; }
#
# .input-range__label-container {
#   left: -50%;
#   position: relative; }
#
# .input-range__label--max .input-range__label-container {
#   left: 50%; }
#
# .input-range__track {
#   background: black;
#   border-radius: 0.3rem;
#   cursor: pointer;
#   display: block;
#   height: 0.3rem;
#   position: relative;
#   transition: left 0.15s ease-out, width 0.15s ease-out; }
#
# .input-range--disabled .input-range__track {
#   background: black; }
#
# .input-range__track--background {
#   left: 0;
#   margin-top: -0.15rem;
#   position: absolute;
#   right: 0;
#   top: 50%; }
#
# .input-range__track--active {
#   background: black; }
#
# /* mapchartChart Styles */
# /* full screen container */
# .mapchart {
#   position: relative;
#   width: 90%;
#   height: 80%;
#   margin-left: 5%;
#   padding-left: 1%;
#   background-color: white; }
#
# /* legend seciton */
# .mapchart-legend-container {
#   z-index: 999;
#   position: absolute;
#   display: inline-block;
#   background-color: white;
#   top: 0;
#   left: 0;
#   width: 18rem;
#   height: 100%;
#   font-variant: small-caps;
#   color: white;
#   box-shadow: 0 0 2px 1px white; }
#
# .mapchart-legend-section {
#   position: relative;
#   margin: 1.5rem 2rem;
#   z-index: 10; }
#
# .mapchart-legend-section-dial {
#   position: relative;
#   margin: 0rem 1rem;
#   z-index: 10; }
#
# .mapchart-legend-section-1col {
#   position: relative;
#   text-align: center;
#   }
#
# .mapchart-legend-section-2col {
#   position: relative;
#   width: 50%;
#   display: inline-block;
#   text-align: center; }
#
# .mapchart-legend-heading {
#   font-size: 1.3rem; }
#
# .mapchart-circ-value {
#   position: absolute;
#   text-align: center;
#   color: black;
#   width: 100%;
#   top: 36%;
#   font-size: 1.3rem; }
#
# .mapchart-key-ul {
#   list-style-type: none;
#   padding-left: 0;
#   margin: 0; }
#
# .mapchart-perf-title {
#   font-size: 1.1rem; }
#
# .mapchart-perf-cube {
#   display: inline-block;
#   vertical-align: top;
#   margin-top: 0.25rem;
#   font-size: 1.2rem; }
#
# .legend-img {
#   width: 2rem; }
#
# .mapchart-bank-list {
#   font-size: 0.9rem;
#   width: 100%; }
#
# .mapchart-perf {
#   display: inline-block;
#   width: 2rem;
#   height: 0.9rem;
#   margin-right: 0.25rem;
#   text-align: center; }
#
# .mapchart-sel0 {
#   background-color: #1082d6; }
#
# .mapchart-sel1 {
#   background-color: #6baed6; }
#
# .mapchart-sel2 {
#   background-color: #7b8ed8; }
#
# .mapchart-sel3 {
#   background-color: #e26798; }
#
# .mapchart-sel4 {
#   background-color: #ff0068; }
#
# .mapchart-legend-button {
#   color: #888888;
#   width: 100%;
#   font-size: 1.2rem;
#   padding: 1.25rem 0rem;
#   text-align: center;
#   background-color: #1f1f1f;
#   cursor: pointer; }
#
# .mapchart-legend-button:hover {
#   color: white; }
#
# .a-button {
#   text-decoration: none;
#   color: #888888; }
#
# .a-button:hover {
#   color: white; }
#
# .mapchart-legend-button-small {
#   width: 100%;
#   color: #888888;
#   font-size: 1.2rem;
#   padding: 0.25rem 0rem;
#   text-align: center;
#   background-color: #1f1f1f;
#   cursor: pointer; }
#
# .mapchart-legend-button-small:hover {
#   color: white; }
#
# .mapchart-legend-sink {
#   position: absolute;
#   bottom: 0;
#   width: 100%; }
#
# /* map section */
# .mapboxgl-ctrl.mapboxgl-ctrl-attrib {
#   display: none; }
#
# .mapboxgl-ctrl-bottom-left {
#   display: none; }
#
# .mapchart-heading-body {
#   position: relative;
#   text-align: center;
#   z-index: 999;
#   margin-left: 18rem;
#   width: calc(100% - 18rem);
#   background-color: rgba(25, 26, 26, 0.8); }
#
# .mapchart-heading-container {
#   display: inline-block; }
#
# .mapchart-header-title {
#   padding-top: 0.7rem;
#   font-size: 2rem;
#   font-variant: small-caps;
#   text-align: center; }
#
# .mapchart-total-bar-cudf {
#   text-align: center;
#   height: 0.25rem;
#   width: 100%;
#   margin-bottom: 0.7rem;
#   background-color: #76b900;
#   transition: all 0.6s ease; }
#
# .mapchart-total-bar-pandas {
#   text-align: center;
#   height: 0.25rem;
#   width: 100%;
#   margin-bottom: 0.7rem;
#   background-color: #0071c5;
#   transition: all 0.6s ease; }
#
# .percent {
#   font-size: 1.3rem; }
#
# .mapchart-map-body {
#   position: absolute;
#   vertical-align: top;
#   display: inline-block;
#   background-color: rgba(0, 0, 0, 0.3);
#   width: 100%;
#   height: 100%; }
#
# /* chart section */
# .mapchart-chart-body {
#   position: relative;
#   background-color: rgba(25, 26, 26, 0.8); }
#
# .mapchart-col1-container {
#   display: inline-block;
#   vertical-align: top;
#   position: relative;
#   margin-left: 10%;
#   width: 80%;
#   height: 80%; }
#
# .mapchart-col2-container {
#   display: inline-block;
#   vertical-align: top;
#   position: relative;
#   width: 45%;
#   height: 100%;
#   margin: 2%; }
#
# .mapchart-col3-container {
#   display: inline-block;
#   vertical-align: top;
#   position: relative;
#   width: 28.32%;
#   height: 100%;
#   padding: 0% 2%; }
#
# .mapChart-chart-reset {
#   cursor: pointer;
#   width: 100%;
#   text-align: center;
#   margin-top: 1rem;
#   font-variant: small-caps;
#   color: #888888; }
#
# .mapChart-chart-reset:hover {
#   color: white; }
#
# .VictoryContainer {
#   overflow: hidden;
#   z-index: 99; }
#
# /* super wide screens */
# @media only screen and (min-width: 2000px) {
#   .mapchart-col2-container {
#     position: relative;
#     width: 92%;
#     height: 42%;
#     padding: 2% 2%; }
#   .mapchart-col3-container {
#     position: relative;
#     width: 80%;
#     height: 22%;
#     padding: 7% 10%; } }
#
# /* status stripes */
# .stripes {
#   transition: all 0.6s ease;
#   animation: barberpole 1s linear infinite;
#   background-size: 30px 30px;
#   background-image: linear-gradient(45deg, rgba(0, 0, 0, 0.2) 25%, transparent 25%, transparent 50%, rgba(0, 0, 0, 0.2) 50%, rgba(0, 0, 0, 0.2) 75%, transparent 75%, transparent); }
#
# @keyframes barberpole {
#   from {
#     background-position: 0 0; }
#   to {
#     background-position: 60px 30px; } }
#
# &lt;/style&gt;&lt;/head&gt;
#   &lt;body&gt;
#   	&lt;div id=&quot;root&quot;&gt;&lt;/div&gt;
#  &lt;script type=&quot;text/javascript&quot;&gt;
#  !function(e){var t={};function n(r){if(t[r])return t[r].exports;var o=t[r]={i:r,l:!1,exports:{}};return e[r].call(o.exports,o,o.exports,n),o.l=!0,o.exports}n.m=e,n.c=t,n.d=function(e,t,r){n.o(e,t)||Object.defineProperty(e,t,{enumerable:!0,get:r})},n.r=function(e){&quot;undefined&quot;!=typeof Symbol&amp;&amp;Symbol.toStringTag&amp;&amp;Object.defineProperty(e,Symbol.toStringTag,{value:&quot;Module&qu

# %%
cux.dimension(data={"borrower_credit_score":{"type":"histogram","bin_size":50}})
# Out:
#            <iframe name="borrower_credit_score" class="borrower_credit_score" width="100%" srcdoc="
# &lt;!DOCTYPE html&gt;
# &lt;html&gt;
#   &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot; /&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;
#     &lt;title&gt;RAPIDS Viz Demo&lt;/title&gt;
#   &lt;link rel=&quot;shortcut icon&quot; href=&quot;./favicon.png&quot;&gt;&lt;style&gt;
#
#   @import url(https://fonts.googleapis.com/css?family=Cabin:400,700);
# /* global  styles */
# body {
#   font-family: &#x27;Cabin&#x27;, sans-serif;
#   font-size: 15px;
#   margin: 0;
#   padding: 0;
#   background-color: white;
#   color: black; }
#
# /* barChart Styles */
# /* input range slider */
# .input-range {
#   z-index: 9999; }
#
# .input-range {
#   height: 1rem;
#   position: relative;
#   width: 100%; }
#
# .input-range__slider {
#   appearance: none;
#   background: black;
#   border: 1px solid black;
#   border-radius: 100%;
#   cursor: pointer;
#   display: block;
#   height: 1rem;
#   margin-left: -0.5rem;
#   margin-top: -0.65rem;
#   outline: none;
#   position: absolute;
#   top: 50%;
#   transition: transform 0.15s ease-out, box-shadow 0.15s ease-out;
#   width: 1rem; }
#
# .input-range__slider:active {
#   transform: scale(1.3); }
#
# .input-range__slider:focus {
#   box-shadow: 0 0 0 5px rgba(63, 81, 181, 0.2); }
#
# .input-range--disabled .input-range__slider {
#   background: black;
#   border: 1px solid rgba(63, 81, 181, 0.2);
#   box-shadow: none;
#   transform: none; }
#
# .input-range__slider-container {
#   transition: left 0.15s ease-out; }
#
# .input-range__label {
#   color: black;
#   font-family: &quot;Helvetica Neue&quot;, san-serif;
#   font-size: 0.8rem;
#   transform: translateZ(0);
#   white-space: nowrap; }
#
# .input-range__label--min,
# .input-range__label--max {
#   bottom: -1.4rem;
#   position: absolute; }
#
# .input-range__label--min {
#   left: 0; }
#
# .input-range__label--max {
#   right: 0; }
#
# .input-range__label--value {
#   position: absolute;
#   top: -1.8rem; }
#
# .input-range__label-container {
#   left: -50%;
#   position: relative; }
#
# .input-range__label--max .input-range__label-container {
#   left: 50%; }
#
# .input-range__track {
#   background: black;
#   border-radius: 0.3rem;
#   cursor: pointer;
#   display: block;
#   height: 0.3rem;
#   position: relative;
#   transition: left 0.15s ease-out, width 0.15s ease-out; }
#
# .input-range--disabled .input-range__track {
#   background: black; }
#
# .input-range__track--background {
#   left: 0;
#   margin-top: -0.15rem;
#   position: absolute;
#   right: 0;
#   top: 50%; }
#
# .input-range__track--active {
#   background: black; }
#
# /* mapchartChart Styles */
# /* full screen container */
# .mapchart {
#   position: relative;
#   width: 90%;
#   height: 80%;
#   margin-left: 5%;
#   padding-left: 1%;
#   background-color: white; }
#
# /* legend seciton */
# .mapchart-legend-container {
#   z-index: 999;
#   position: absolute;
#   display: inline-block;
#   background-color: white;
#   top: 0;
#   left: 0;
#   width: 18rem;
#   height: 100%;
#   font-variant: small-caps;
#   color: white;
#   box-shadow: 0 0 2px 1px white; }
#
# .mapchart-legend-section {
#   position: relative;
#   margin: 1.5rem 2rem;
#   z-index: 10; }
#
# .mapchart-legend-section-dial {
#   position: relative;
#   margin: 0rem 1rem;
#   z-index: 10; }
#
# .mapchart-legend-section-1col {
#   position: relative;
#   text-align: center;
#   }
#
# .mapchart-legend-section-2col {
#   position: relative;
#   width: 50%;
#   display: inline-block;
#   text-align: center; }
#
# .mapchart-legend-heading {
#   font-size: 1.3rem; }
#
# .mapchart-circ-value {
#   position: absolute;
#   text-align: center;
#   color: black;
#   width: 100%;
#   top: 36%;
#   font-size: 1.3rem; }
#
# .mapchart-key-ul {
#   list-style-type: none;
#   padding-left: 0;
#   margin: 0; }
#
# .mapchart-perf-title {
#   font-size: 1.1rem; }
#
# .mapchart-perf-cube {
#   display: inline-block;
#   vertical-align: top;
#   margin-top: 0.25rem;
#   font-size: 1.2rem; }
#
# .legend-img {
#   width: 2rem; }
#
# .mapchart-bank-list {
#   font-size: 0.9rem;
#   width: 100%; }
#
# .mapchart-perf {
#   display: inline-block;
#   width: 2rem;
#   height: 0.9rem;
#   margin-right: 0.25rem;
#   text-align: center; }
#
# .mapchart-sel0 {
#   background-color: #1082d6; }
#
# .mapchart-sel1 {
#   background-color: #6baed6; }
#
# .mapchart-sel2 {
#   background-color: #7b8ed8; }
#
# .mapchart-sel3 {
#   background-color: #e26798; }
#
# .mapchart-sel4 {
#   background-color: #ff0068; }
#
# .mapchart-legend-button {
#   color: #888888;
#   width: 100%;
#   font-size: 1.2rem;
#   padding: 1.25rem 0rem;
#   text-align: center;
#   background-color: #1f1f1f;
#   cursor: pointer; }
#
# .mapchart-legend-button:hover {
#   color: white; }
#
# .a-button {
#   text-decoration: none;
#   color: #888888; }
#
# .a-button:hover {
#   color: white; }
#
# .mapchart-legend-button-small {
#   width: 100%;
#   color: #888888;
#   font-size: 1.2rem;
#   padding: 0.25rem 0rem;
#   text-align: center;
#   background-color: #1f1f1f;
#   cursor: pointer; }
#
# .mapchart-legend-button-small:hover {
#   color: white; }
#
# .mapchart-legend-sink {
#   position: absolute;
#   bottom: 0;
#   width: 100%; }
#
# /* map section */
# .mapboxgl-ctrl.mapboxgl-ctrl-attrib {
#   display: none; }
#
# .mapboxgl-ctrl-bottom-left {
#   display: none; }
#
# .mapchart-heading-body {
#   position: relative;
#   text-align: center;
#   z-index: 999;
#   margin-left: 18rem;
#   width: calc(100% - 18rem);
#   background-color: rgba(25, 26, 26, 0.8); }
#
# .mapchart-heading-container {
#   display: inline-block; }
#
# .mapchart-header-title {
#   padding-top: 0.7rem;
#   font-size: 2rem;
#   font-variant: small-caps;
#   text-align: center; }
#
# .mapchart-total-bar-cudf {
#   text-align: center;
#   height: 0.25rem;
#   width: 100%;
#   margin-bottom: 0.7rem;
#   background-color: #76b900;
#   transition: all 0.6s ease; }
#
# .mapchart-total-bar-pandas {
#   text-align: center;
#   height: 0.25rem;
#   width: 100%;
#   margin-bottom: 0.7rem;
#   background-color: #0071c5;
#   transition: all 0.6s ease; }
#
# .percent {
#   font-size: 1.3rem; }
#
# .mapchart-map-body {
#   position: absolute;
#   vertical-align: top;
#   display: inline-block;
#   background-color: rgba(0, 0, 0, 0.3);
#   width: 100%;
#   height: 100%; }
#
# /* chart section */
# .mapchart-chart-body {
#   position: relative;
#   background-color: rgba(25, 26, 26, 0.8); }
#
# .mapchart-col1-container {
#   display: inline-block;
#   vertical-align: top;
#   position: relative;
#   margin-left: 10%;
#   width: 80%;
#   height: 80%; }
#
# .mapchart-col2-container {
#   display: inline-block;
#   vertical-align: top;
#   position: relative;
#   width: 45%;
#   height: 100%;
#   margin: 2%; }
#
# .mapchart-col3-container {
#   display: inline-block;
#   vertical-align: top;
#   position: relative;
#   width: 28.32%;
#   height: 100%;
#   padding: 0% 2%; }
#
# .mapChart-chart-reset {
#   cursor: pointer;
#   width: 100%;
#   text-align: center;
#   margin-top: 1rem;
#   font-variant: small-caps;
#   color: #888888; }
#
# .mapChart-chart-reset:hover {
#   color: white; }
#
# .VictoryContainer {
#   overflow: hidden;
#   z-index: 99; }
#
# /* super wide screens */
# @media only screen and (min-width: 2000px) {
#   .mapchart-col2-container {
#     position: relative;
#     width: 92%;
#     height: 42%;
#     padding: 2% 2%; }
#   .mapchart-col3-container {
#     position: relative;
#     width: 80%;
#     height: 22%;
#     padding: 7% 10%; } }
#
# /* status stripes */
# .stripes {
#   transition: all 0.6s ease;
#   animation: barberpole 1s linear infinite;
#   background-size: 30px 30px;
#   background-image: linear-gradient(45deg, rgba(0, 0, 0, 0.2) 25%, transparent 25%, transparent 50%, rgba(0, 0, 0, 0.2) 50%, rgba(0, 0, 0, 0.2) 75%, transparent 75%, transparent); }
#
# @keyframes barberpole {
#   from {
#     background-position: 0 0; }
#   to {
#     background-position: 60px 30px; } }
#
# &lt;/style&gt;&lt;/head&gt;
#   &lt;body&gt;
#   	&lt;div id=&quot;root&quot;&gt;&lt;/div&gt;
#  &lt;script type=&quot;text/javascript&quot;&gt;
#  !function(e){var t={};function n(r){if(t[r])return t[r].exports;var o=t[r]={i:r,l:!1,exports:{}};return e[r].call(o.exports,o,o.exports,n),o.l=!0,o.exports}n.m=e,n.c=t,n.d=function(e,t,r){n.o(e,t)||Object.defineProperty(e,t,{enumerable:!0,get:r})},n.r=function(e){&quot;undefined&quot;!=typeof Symbol&amp;&amp;Symbol.toStringTag&amp;&amp;Object.defineProperty(e,Symbo

# %%
#render charts in iframes
cux.render()

# %%
#dislay the current dimensions
cux.dimensions
# Out:
# {'borrower_credit_score': <cuXfilter.cuXfilter.dimension at 0x7ff83ca34518>,
#  'combined': <cuXfilter.cuXfilter.dimension at 0x7ff83ca96128>,
#  'delinquency_12_prediction': <cuXfilter.cuXfilter.dimension at 0x7ff83ca34ba8>,
#  'dti': <cuXfilter.cuXfilter.dimension at 0x7ff83ca340f0>}

# %% [markdown]
# ## End Connection and clear gpu memory on the server

# %%
cux.end_connection()
